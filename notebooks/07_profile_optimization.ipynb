# %%
from time import perf_counter


start = perf_counter()

result = run_one(
    threshold=4.5,
    replicate=0,
    master_seed=master_seed_pilot,
)

elapsed = perf_counter() - start

print(f"Time: {elapsed:.3f} s")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 from time import perf_counter
#       2
#       3 start = perf_counter()
#       4
# ----> 5 result = run_one(
#       6     threshold=4.5,
#       7     replicate=0,
#       8     master_seed=master_seed_pilot,
#
# NameError: name 'run_one' is not defined
